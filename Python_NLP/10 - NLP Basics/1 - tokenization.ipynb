# %% [markdown]
# ## NLP Basics
#
# ### Tokenization

# %%
# %pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached regex-2026.1.15-cp313-cp313-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached regex-2026.1.15-cp313-cp313-win_amd64.whl (277 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
# ...

# %%
corpus = """ Hi, my name is Sri. I am a Data Analyst. I love coding in Python! 
I also enjoy working with data and creating visualizations. 
Feel free to reach out to me for any data-related projects. 
Thank you! 
Have a great day! """

# %%
print(corpus)
# Out:
#  Hi, my name is Sri. I am a Data Analyst. I love coding in Python!
# I also enjoy working with data and creating visualizations.
# Feel free to reach out to me for any data-related projects.
# Thank you!
# Have a great day!

# %% [markdown]
# #### Tokenization
# Sentence --> paragraphs

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Srilathaa
# [nltk_data]     Vasu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Srilathaa
# [nltk_data]     Vasu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

documents = sent_tokenize(corpus)
documents
# Out:
# [' Hi, my name is Sri.',
#  'I am a Data Analyst.',
#  'I love coding in Python!',
#  'I also enjoy working with data and creating visualizations.',
#  'Feel free to reach out to me for any data-related projects.',
#  'Thank you!',
#  'Have a great day!']

# %% [markdown]
# #### Tokenization
# Paragraph-->words
# sentence--->words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hi',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Sri',
#  '.',
#  'I',
#  'am',
#  'a',
#  'Data',
#  'Analyst',
#  '.',
#  'I',
#  'love',
#  'coding',
#  'in',
#  'Python',
#  '!',
#  'I',
#  'also',
#  'enjoy',
#  'working',
#  'with',
#  'data',
#  'and',
#  'creating',
#  'visualizations',
#  '.',
#  'Feel',
#  'free',
#  'to',
#  'reach',
#  'out',
#  'to',
#  'me',
#  'for',
#  'any',
#  'data-related',
#  'projects',
#  '.',
#  'Thank',
#  'you',
#  '!',
#  'Have',
#  'a',
#  'great',
#  'day',
#  '!']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hi',
#  ',',
#  'my',
#  'name',
#  'is',
#  'Sri',
#  '.',
#  'I',
#  'am',
#  'a',
#  'Data',
#  'Analyst',
#  '.',
#  'I',
#  'love',
#  'coding',
#  'in',
#  'Python',
#  '!',
#  'I',
#  'also',
#  'enjoy',
#  'working',
#  'with',
#  'data',
#  'and',
#  'creating',
#  'visualizations',
#  '.',
#  'Feel',
#  'free',
#  'to',
#  'reach',
#  'out',
#  'to',
#  'me',
#  'for',
#  'any',
#  'data',
#  '-',
#  'related',
#  'projects',
#  '.',
#  'Thank',
#  'you',
#  '!',
#  'Have',
#  'a',
#  'great',
#  'day',
#  '!']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer = tokenizer.tokenize(corpus)
print(tokenizer)
# Out:
# ['Hi', ',', 'my', 'name', 'is', 'Sri.', 'I', 'am', 'a', 'Data', 'Analyst.', 'I', 'love', 'coding', 'in', 'Python', '!', 'I', 'also', 'enjoy', 'working', 'with', 'data', 'and', 'creating', 'visualizations.', 'Feel', 'free', 'to', 'reach', 'out', 'to', 'me', 'for', 'any', 'data-related', 'projects.', 'Thank', 'you', '!', 'Have', 'a', 'great', 'day', '!']
